# %% [markdown]
# <a href="https://colab.research.google.com/github/frbrenna/FA_AI_influencers/blob/main/LaunchFooocus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Download Fooocus

# %%
# !git clone https://github.com//lllyasviel/Fooocus.git
# %cd Fooocus
# Out:
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 5226, done.
# remote: Counting objects: 100% (307/307), done.
# remote: Compressing objects: 100% (296/296), done.
# remote: Total 5226 (delta 12), reused 294 (delta 7), pack-reused 4919
# Receiving objects: 100% (5226/5226), 32.23 MiB | 32.07 MiB/s, done.
# Resolving deltas: 100% (3009/3009), done.
# /content/Fooocus

# %% [markdown]
# Install Fooocus framework

# %%
# !pip install -r requirements_versions.txt
# Out:
# Collecting torchsde==0.2.5 (from -r requirements_versions.txt (line 1))
#   Downloading torchsde-0.2.5-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 kB 1.1 MB/s eta 0:00:00
# Collecting einops==0.4.1 (from -r requirements_versions.txt (line 2))
#   Downloading einops-0.4.1-py3-none-any.whl (28 kB)
# Collecting transformers==4.30.2 (from -r requirements_versions.txt (line 3))
#   Downloading transformers-4.30.2-py3-none-any.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 45.9 MB/s eta 0:00:00
# Collecting safetensors==0.3.1 (from -r requirements_versions.txt (line 4))
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 41.1 MB/s eta 0:00:00
# Collecting accelerate==0.21.0 (from -r requirements_versions.txt (line 5))
#   Downloading accelerate-0.21.0-py3-none-any.whl (244 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 23.5 MB/s eta 0:00:00
# Collecting pyyaml==6.0 (from -r requirements_versions.txt (line 6))
#   Downloading PyYAML-6.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (682 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 682.2/682.2 kB 44.3 MB/s eta 0:00:00
# Collecting Pillow==9.2.0 (from -r requirements_versions.txt (line 7))
#   Downloading Pillow-9.2.0-cp310-cp310-manylinux_2_28_x86_64.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 62.5 MB/s eta 0:00:00
# Collecting scipy==1.9.3 (from -r requirements_versions.txt (line 8))
#   Downloading scipy-1.9.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (33.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.7/33.7 MB 20.1 MB/s eta 0:00:00
# Collecting tqdm==4.64.1 (from -r requirements_versions.txt (line 9))
#   Downloading tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: psutil==5.9.5 in /usr/local/lib/python3.10/dist-packages (from -r requirements_versions.txt (line 10)) (5.9.5)
# Collecting pytorch_lightning==1.9.4 (from -r requirements_versions.txt (line 11))
#   Downloading pytorch_lightning-1.9.4-py3-none-any.whl (827 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 827.8/827.8 kB 53.6 MB/s eta 0:00:00
# Collecting omegaconf==2.2.3 (from -r requirements_versions.txt (line 12))
#   Downloading omegaconf-2.2.3-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.3/79.3 kB 10.7 MB/s eta 0:00:00
# Collecting gradio==3.41.2 (from -r requirements_versions.txt (line 13))
#   Downloading gradio-3.41.2-py3-none-any.whl (20.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.1/20.1 MB 73.6 MB/s eta 0:00:00
# Collecting pygit2==1.12.2 (from -r requirements_versions.txt (line 14))
#   Downloading pygit2-1.12.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 73.3 MB/s eta 0:00:00
# Collecting opencv-contrib-python==4.8.0.74 (from -r requirements_versions.txt (line 15))
#   Downloading opencv_contrib_python-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (67.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 MB 8.7 MB/s eta 0:00:00
# Collecting httpx==0.24.1 (from -r requirements_versions.txt (line 16))
#   Downloading httpx-0.24.1-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 10.4 MB/s eta 0:00:00
# Collecting onnxruntime==1.16.3 (from -r requirements_versions.txt (line 17))
#   Downloading onnxruntime-1.16.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 84.8 MB/s eta 0:00:00
# Collecting timm==0.9.2 (from -r requirements_versions.txt (line 18))
#   Downloading timm-0.9.2-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 53.9 MB/s eta 0:00:00
# Collecting boltons>=20.2.1 (from torchsde==0.2.5->-r requirements_versions.txt (line 1))
#   Downloading boltons-23.1.1-py2.py3-none-any.whl (195 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.3/195.3 kB 23.2 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from torchsde==0.2.5->-r requirements_versions.txt (line 1)) (2.1.0+cu121)
# Collecting trampoline>=0.1.2 (from torchsde==0.2.5->-r requirements_versions.txt (line 1))
#   Downloading trampoline-0.1.2-py3-none-any.whl (5.2 kB)
# Requirement already satisfied: numpy>=1.19.* in /usr/local/lib/python3.10/dist-packages (from torchsde==0.2.5->-r requirements_versions.txt (line 1)) (1.23.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2->-r requirements_versions.txt (line 3)) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2->-r requirements_versions.txt (line 3)) (0.20.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2->-r requirements_versions.txt (line 3)) (23.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2->-r requirements_versions.txt (line 3)) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2->-r requirements_versions.txt (line 3)) (2.31.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers==4.30.2->-r requirements_versions.txt (line 3))
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 90.8 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>2021.06.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning==1.9.4->-r requirements_versions.txt (line 11)) (2023.6.0)
# Collecting torchmetrics>=0.7.0 (from pytorch_lightning==1.9.4->-r requirements_versions.txt (line 11))
#   Downloading torchmetrics-1.3.0.post0-py3-none-any.whl (840 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.2/840.2 kB 63.7 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning==1.9.4->-r requirements_versions.txt (line 11)) (4.5.0)
# Collecting lightning-utilities>=0.6.0.post0 (from pytorch_lightning==1.9.4->-r requirements_versions.txt (line 11))
#   Downloading lightning_utilities-0.10.1-py3-none-any.whl (24 kB)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf==2.2.3->-r requirements_versions.txt (line 12))
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 15.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting aiofiles<24.0,>=22.0 (from gradio==3.41.2->-r requirements_versions.txt (line 13))
#   Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.41.2->-r requirements_versions.txt (line 13)) (4.2.2)
# Collecting fastapi (from gradio==3.41.2->-r requirements_versions.txt (line 13))
#   Downloading fastapi-0.109.0-py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 12.7 MB/s eta 0:00:00
# Collecting ffmpy (from gradio==3.41.2->-r requirements_versions.txt (line 13))
#   Downloading ffmpy-0.3.1.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Collecting gradio-client==0.5.0 (from gradio==3.41.2->-r requirements_versions.txt (line 13))
#   Downloading gradio_client-0.5.0-py3-none-any.whl (298 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.2/298.2 kB 29.3 MB/s eta 0:00:00
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.10/dist-packages (from gradio==3.41.2->-r requirements_versions.txt (line 13)) (6.1.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.41.2->-r requirements_versions.txt (line 13)) (3.1.3)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.41.2->-r requirements_versions.txt (line 13)) (2.1.3)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.41.2->-r requirements_versions.txt (line 13)) (3.7.1)
# Collecting orjson~=3.0 (from gradio==3.41.2->-r requirements_versions.txt (line 13))
#   Downloading orjson-3.9.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 15.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.41.2->-r requirements_versions.txt (line 13)) (1.5.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from gradio==3.41.2->-r requirements_versions.txt (line 13)) (1.10.13)
# Collecting pydub (from gradio==3.41.2->-r requirements_versions.txt (line 13))
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting python-multipart (from gradio==3.41.2->-r requirements_versions.txt (line 13))
#   Downloading python_multipart-0.0.6-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 5.3 MB/s eta 0:00:00
# Collecting semantic-version~=2.0 (from gradio==3.41.2->-r requirements_versions.txt (line 13))
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting uvicorn>=0.14.0 (from gradio==3.41.2->-r requirements_versions.txt (line 13))
#   Downloading uvicorn-0.26.0-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.5/60.5 kB 8.4 MB/s eta 0:00:00
# Collecting websockets<12.0,>=10.0 (from gradio==3.41.2->-r requirements_versions.txt (line 13))
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 13.4 MB/s eta 0:00:00
# Requirement already satisfied: cffi>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from pygit2==1.12.2->-r requirements_versions.txt (line 14)) (1.16.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx==0.24.1->-r requirements_versions.txt (line 16)) (2023.11.17)
# Collecting httpcore<0.18.0,>=0.15.0 (from httpx==0.24.1->-r requirements_versions.txt (line 16))
#   Downloading httpcore-0.17.3-py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx==0.24.1->-r requirements_versions.txt (line 16)) (3.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.24.1->-r requirements_versions.txt (line 16)) (1.3.0)
# Collecting coloredlogs (from onnxruntime==1.16.3->-r requirements_versions.txt (line 17))
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime==1.16.3->-r requirements_versions.txt (line 17)) (23.5.26)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime==1.16.3->-r requirements_versions.txt (line 17)) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime==1.16.3->-r requirements_versions.txt (line 17)) (1.12)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm==0.9.2->-r requirements_versions.txt (line 18)) (0.16.0+cu121)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==3.41.2->-r requirements_versions.txt (line 13)) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==3.41.2->-r requirements_versions.txt (line 13)) (4.19.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==3.41.2->-r requirements_versions.txt (line 13)) (0.12.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.9.1->pygit2==1.12.2->-r requirements_versions.txt (line 14)) (2.21)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>2021.06.0->pytorch_lightning==1.9.4->-r requirements_versions.txt (line 11)) (3.9.1)
# Collecting h11<0.15,>=0.13 (from httpcore<0.18.0,>=0.15.0->httpx==0.24.1->-r requirements_versions.txt (line 16))
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.10/dist-packages (from httpcore<0.18.0,>=0.15.0->httpx==0.24.1->-r requirements_versions.txt (line 16)) (3.7.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.6.0.post0->pytorch_lightning==1.9.4->-r requirements_versions.txt (line 11)) (67.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==3.41.2->-r requirements_versions.txt (line 13)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==3.41.2->-r requirements_versions.txt (line 13)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==3.41.2->-r requirements_versions.txt (line 13)) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==3.41.2->-r requirements_versions.txt (line 13)) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==3.41.2->-r requirements_versions.txt (line 13)) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==3.41.2->-r requirements_versions.txt (line 13)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio==3.41.2->-r requirements_versions.txt (line 13)) (2023.3.post1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.30.2->-r requirements_versions.txt (line 3)) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.30.2->-r requirements_versions.txt (line 3)) (2.0.7)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->torchsde==0.2.5->-r requirements_versions.txt (line 1)) (3.2.1)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->torchsde==0.2.5->-r requirements_versions.txt (line 1)) (2.1.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn>=0.14.0->gradio==3.41.2->-r requirements_versions.txt (line 13)) (8.1.7)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime==1.16.3->-r requirements_versions.txt (line 17))
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 12.6 MB/s eta 0:00:00
# Collecting starlette<0.36.0,>=0.35.0 (from fastapi->gradio==3.41.2->-r requirements_versions.txt (line 13))
#   Downloading starlette-0.35.1-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.1/71.1 kB 8.7 MB/s eta 0:00:00
# Collecting typing-extensions>=4.0.0 (from pytorch_lightning==1.9.4->-r requirements_versions.txt (line 11))
#   Downloading typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime==1.16.3->-r requirements_versions.txt (line 17)) (1.3.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning==1.9.4->-r requirements_versions.txt (line 11)) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning==1.9.4->-r requirements_versions.txt (line 11)) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning==1.9.4->-r requirements_versions.txt (line 11)) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning==1.9.4->-r requirements_versions.txt (line 11)) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning==1.9.4->-r requirements_versions.txt (line 11)) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning==1.9.4->-r requirements_versions.txt (line 11)) (4.0.3)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->httpcore<0.18.0,>=0.15.0->httpx==0.24.1->-r requirements_versions.txt (line 16)) (1.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.41.2->-r requirements_versions.txt (line 13)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.41.2->-r requirements_versions.txt (line 13)) (0.32.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.41.2->-r requirements_versions.txt (line 13)) (0.17.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio==3.41.2->-r requirements_versions.txt (line 13)) (1.16.0)
# Building wheels for collected packages: antlr4-python3-runtime, ffmpy
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=760e01383ebcbde67843b91ddf7ec89f7978a1890271d4488d3c09f41f0ae323
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
#   Building wheel for ffmpy (setup.py) ... done
#   Created wheel for ffmpy: filename=ffmpy-0.3.1-py3-none-any.whl size=5579 sha256=da93b47f700ec3db0fa0043d4847a0e1bce4c04d818cab20265fee60e94ff2fb
#   Stored in directory: /root/.cache/pip/wheels/01/a6/d1/1c0828c304a4283b2c1639a09ad86f83d7c487ef34c6b4a1bf
# Successfully built antlr4-python3-runtime ffmpy
# Installing collected packages: trampoline, tokenizers, safetensors, pydub, ffmpy, einops, boltons, antlr4-python3-runtime, websockets, typing-extensions, tqdm, semantic-version, scipy, pyyaml, python-multipart, Pillow, orjson, opencv-contrib-python, humanfriendly, h11, aiofiles, uvicorn, starlette, pygit2, omegaconf, lightning-utilities, httpcore, coloredlogs, transformers, torchsde, torchmetrics, onnxruntime, httpx, fastapi, accelerate, timm, pytorch_lightning, gradio-client, gradio
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.15.0
#     Uninstalling tokenizers-0.15.0:
#       Successfully uninstalled tokenizers-0.15.0
#   Attempting uninstall: safetensors
#     Found existing installation: safetensors 0.4.1
#     Uninstalling safetensors-0.4.1:
#       Successfully uninstalled safetensors-0.4.1
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.1
#     Uninstalling tqdm-4.66.1:
#       Successfully uninstalled tqdm-4.66.1
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.11.4
#     Uninstalling scipy-1.11.4:
#       Successfully uninstalled scipy-1.11.4
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0.1
#     Uninstalling PyYAML-6.0.1:
#       Successfully uninstalled PyYAML-6.0.1
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
#   Attempting uninstall: opencv-contrib-python
#     Found existing installation: opencv-contrib-python 4.8.0.76
#     Uninstalling opencv-contrib-python-4.8.0.76:
#       Successfully uninstalled opencv-contrib-python-4.8.0.76
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.35.2
#     Uninstalling transformers-4.35.2:
#       Successfully uninstalled transformers-4.35.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires kaleido, which is not installed.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# tensorflow-probability 0.22.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.9.0 which is incompatible.
# Successfully installed Pillow-9.2.0 accelerate-0.21.0 aiofiles-23.2.1 antlr4-python3-runtime-4.9.3 boltons-23.1.1 coloredlogs-15.0.1 einops-0.4.1 fastapi-0.109.0 ffmpy-0.3.1 gradio-3.41.2 gradio-client-0.5.0 h11-0.14.0 httpcore-0.17.3 httpx-0.24.1 humanfriendly-10.0 lightning-utilities-0.10.1 omegaconf-2.2.3 onnxruntime-1.16.3 opencv-contrib-python-4.8.0.74 orjson-3.9.12 pydub-0.25.1 pygit2-1.12.2 python-multipart-0.0.6 pytorch_lightning-1.9.4 pyyaml-6.0 safetensors-0.3.1 scipy-1.9.3 semantic-version-2.10.0 starlette-0.35.1 timm-0.9.2 tokenizers-0.13.3 torchmetrics-1.3.0.post0 torchsde-0.2.5 tqdm-4.64.1 trampoline-0.1.2 transformers-4.30.2 typing-extensions-4.9.0 uvicorn-0.26.0 websockets-11.0.3

# %% [markdown]
# Launch it

# %%
# !python entry_with_update.py --share
# Out:
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share']
# Python 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# Fooocus version: 2.1.862
# Downloading: "https://huggingface.co/lllyasviel/fav_models/resolve/main/fav/juggernautXL_version6Rundiffusion.safetensors" to /content/Fooocus/models/checkpoints/juggernautXL_version6Rundiffusion.safetensors
#
# 100% 6.62G/6.62G [00:55<00:00, 129MB/s]
# Downloading: "https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_offset_example-lora_1.0.safetensors" to /content/Fooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors
#
# 100% 47.3M/47.3M [00:00<00:00, 168MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/xlvaeapp.pth" to /content/Fooocus/models/vae_approx/xlvaeapp.pth
#
# 100% 209k/209k [00:00<00:00, 10.1MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/vaeapp_sd15.pt" to /content/Fooocus/models/vae_approx/vaeapp_sd15.pth
#
# 100% 209k/209k [00:00<00:00, 40.0MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/xl-to-v1_interposer-v3.1.safetensors" to /content/Fooocus/models/vae_approx/xl-to-v1_interposer-v3.1.safetensors
#
# 100% 6.25M/6.25M [00:00<00:00, 97.3MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/fooocus_expansion.bin" to /content/Fooocus/models/prompt_expansion/fooocus_expansion/pytorch_model.bin
#
# 100% 335M/335M [00:01<00:00, 203MB/s]
# Exception in thread Thread-3 (worker):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "/content/Fooocus/modules/async_worker.py", line 25, in worker
#     import modules.default_pipeline as pipeline
#   File "/content/Fooocus/modules/default_pipeline.py", line 1, in <module>
#     import modules.core as core
#   File "/content/Fooocus/modules/core.py", line 1, in <module>
#     from modules.patch import patch_all
#   File "/content/Fooocus/modules/patch.py", line 5, in <module>
#     import ldm_patched.modules.model_base
#   File "/content/Fooocus/ldm_patched/modules/model_base.py", line 2, in <module>
#     from ldm_patched.ldm.modules.diffusionmodules.openaimodel import UNetModel
#   File "/content/Fooocus/ldm_patched/ldm/modules/diffusionmodules/openaimodel.py", line 18, in <module>
#     from ..attention import SpatialTransformer, SpatialVideoTransformer, default
#   File "/content/Fooocus/ldm_patched/ldm/modules/attention.py", line 12, in <module>
#     from .sub_quadratic_attention import efficient_dot_product_attention
#   File "/content/Fooocus/ldm_patched/ldm/modules/sub_quadratic_attention.py", line 27, in <module>
#     from ldm_patched.modules import model_management
#   File "/content/Fooocus/ldm_patched/modules/model_management.py", line 118, in <module>
#     total_vram = get_total_memory(get_torch_device()) / (1024 * 1024)
#   File "/content/Fooocus/ldm_patched/modules/model_management.py", line 87, in get_torch_device
#     return torch.device(torch.cuda.current_device())
#   File "/usr/local/lib/python3.10/dist-packages/torch/cuda/__init__.py", line 769, in current_device
#     _lazy_init()
#   File "/usr/local/lib/python3.10/dist-packages/torch/cuda/__init__.py", line 298, in _lazy_init
#     torch._C._cuda_init()
# RuntimeError: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx
# Running on local URL:  http://127.0.0.1:7865
# Running on public URL: https://be6b36259ad818009c.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/gradio/routes.py", line 488, in run_predict
#     output = await app.get_blocks().process_api(
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 1431, in process_api
#     result = await self.call_function(
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 1117, in call_function
#     prediction = await utils.async_iteration(iterator)
#   File "/usr/local/lib/python3.10/dist-packages/gradio/utils.py", line 350, in async_iteration
#     return await iterator.__anext__()
#   File "/usr/local/lib/python3.10/dist-packages/gradio/utils.py", line 343, in __anext__
#     return await anyio.to_thread.run_sync(
#   File "/usr/local/lib/python3.10/dist-packages/anyio/to_thread.py", line 33, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(
#   File "/usr/local/lib/python3.10/dist-packages/anyio/_backends/_asyncio.py", line 877, in run_sync_in_worker_thread
#     return await future
#   File "/usr/local/lib/python3.10/dist-packages/anyio/_backends/_asyncio.py", line 807, in run
#     result = context.run(func, *args)
#   File "/usr/local/lib/python3.10/dist-packages/gradio/utils.py", line 326, in run_sync_iterator_async
#     return next(iterator)
#   File "/usr/local/lib/python3.10/dist-packages/gradio/utils.py", line 695, in gen_wrapper
#     yield from f(*args, **kwargs)
#   File "/content/Fooocus/webui.py", line 27, in generate_clicked
#     import ldm_patched.modules.model_management as model_management
#   File "/content/Fooocus/ldm_patched/modules/model_management.py", line 118, in <module>
#     total_vram = get_total_memory(get_torch_device()) / (1024 * 1024)
#   File "/content/Fooocus/ldm_patched/modules/model_management.py", line 87, in get_torch_device
#     return torch.device(torch.cuda.current_device())
#   File "/usr/local/lib/python3.10/dist-packages/torch/cuda/__init__.py", line 769, in current_device
#     _lazy_init()
#   File "/usr/local/lib/python3.10/dist-packages/torch/cuda/__init__.py", line 298, in _lazy_init
#     torch._C._cuda_init()
# RuntimeError: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/gradio/routes.py", line 488, in run_predict
#     output = await app.get_blocks().process_api(
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 1431, in process_api
#     result = await self.call_function(
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 1117, in call_function
#     prediction = await utils.async_iteration(iterator)
#   File "/usr/local/lib/python3.10/dist-packages/gradio/utils.py", line 350, in async_iteration
#     return await iterator.__anext__()
#   File "/usr/local/lib/python3.10/dist-packages/gradio/utils.py", line 343, in __anext__
#     return await anyio.to_thread.run_sync(
#   File "/usr/local/lib/python3.10/dist-packages/anyio/to_thread.py", line 33, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(
#   File "/usr/local/lib/python3.10/dist-packages/anyio/_backends/_asyncio.py", line 877, in run_sync_in_worker_thread
#     return await future
#   File "/usr/local/lib/python3.10/dist-packages/anyio/_backends/_asyncio.py", line 807, in run
#     result = context.run(func, *args)
#   File "/usr/local/lib/python3.10/dist-packages/gradio/utils.py", line 326, in run_sync_iterator_async
#     return next(iterator)
#   File "/usr/local/lib/python3.10/dist-packages/gradio/utils.py", line 695, in gen_wrapper
#     yield from f(*args, **kwargs)
#   File "/content/Fooocus/webui.py", line 27, in generate_clicked
#     import ldm_patched.modules.model_management as model_management
#   File "/content/Fooocus/ldm_patched/modules/model_management.py", line 118, in <module>
#     total_vram = get_total_memory(get_torch_device()) / (1024 * 1024)
#   File "/content/Fooocus/ldm_patched/modules/model_management.py", line 87, in get_torch_device
#     return torch.device(torch.cuda.current_device())
#   File "/usr/local/lib/python3.10/dist-packages/torch/cuda/__init__.py", line 769, in current_device
#     _lazy_init()
#   File "/usr/local/lib/python3.10/dist-packages/torch/cuda/__init__.py", line 298, in _lazy_init
#     torch._C._cuda_init()
# RuntimeError: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/gradio/routes.py", line 488, in run_predict
#     output = await app.get_blocks().process_api(
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 1431, in process_api
#     result = await self.call_function(
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 1117, in call_function
#     prediction = await utils.async_iteration(iterator)
#   File "/usr/local/lib/python3.10/dist-packages/gradio/utils.py", line 350, in async_iteration
#     return await iterator.__anext__()
#   File "/usr/local/lib/python3.10/dist-packages/gradio/utils.py", line 343, in __anext__
#     return await anyio.to_thread.run_sync(
#   File "/usr/local/lib/python3.10/dist-packages/anyio/to_thread.py", line 33, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(
#   File "/usr/local/lib/python3.10/dist-packages/anyio/_backends/_asyncio.py", line 877, in run_sync_in_worker_thread
#     return await future
#   File "/usr/local/lib/python3.10/dist-packages/anyio/_backends/_asyncio.py", line 807, in run
#     result = context.run(func, *args)
#   File "/usr/local/lib/python3.10/dist-packages/gradio/utils.py", line 326, in run_sync_iterator_async
#     return next(iterator)
#   File "/usr/local/lib/python3.10/dist-packages/gradio/utils.py", line 695, in gen_wrapper
#     yield from f(*args, **kwargs)
#   File "/content/Fooocus/webui.py", line 27, in generate_clicked
#     import ldm_patched.modules.model_management as model_management
#   File "/content/Fooocus/ldm_patched/modules/model_management.py", line 118, in <module>
#     total_vram = get_total_memory(get_torch_device()) / (1024 * 1024)
#   File "/content/Fooocus/ldm_patched/modules/model_management.py", line 87, in get_torch_device
#     return torch.device(torch.cuda.current_device())
#   File "/usr/local/lib/python3.10/dist-packages/torch/cuda/__init__.py", line 769, in current_device
#     _lazy_init()
#   File "/usr/local/lib/python3.10/dist-packages/torch/cuda/__init__.py", line 298, in _lazy_init
#     torch._C._cuda_init()
# RuntimeError: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/gradio/routes.py", line 488, in run_predict
#     output = await app.get_blocks().process_api(
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 1431, in process_api
#     result = await self.call_function(
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 1117, in call_function
#     prediction = await utils.async_iteration(iterator)
#   File "/usr/local/lib/python3.10/dist-packages/gradio/utils.py", line 350, in async_iteration
#     return await iterator.__anext__()
#   File "/usr/local/lib/python3.10/dist-packages/gradio/utils.py", line 343, in __anext__
#     return await anyio.to_thread.run_sync(
#   File "/usr/local/lib/python3.10/dist-packages/anyio/to_thread.py", line 33, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(
#   File "/usr/local/lib/python3.10/dist-packages/anyio/_backends/_asyncio.py", line 877, in run_sync_in_worker_thread
#     return await future
#   File "/usr/local/lib/python3.10/dist-packages/anyio/_backends/_asyncio.py", line 807, in run
#     result = context.run(func, *args)
#   File "/usr/local/lib/python3.10/dist-packages/gradio/utils.py", line 326, in run_sync_iterator_async
#     return next(iterator)
#   File "/usr/local/lib/python3.10/dist-packages/gradio/utils.py", line 695, in gen_wrapper
#     yield from f(*args, **kwargs)
#   File "/content/Fooocus/webui.py", line 27, in generate_clicked
#     import ldm_patched.modules.model_management as model_management
#   File "/content/Fooocus/ldm_patched/modules/model_management.py", line 118, in <module>
#     total_vram = get_total_memory(get_torch_device()) / (1024 * 1024)
#   File "/content/Fooocus/ldm_patched/modules/model_management.py", line 87, in get_torch_device
#     return torch.device(torch.cuda.current_device())
#   File "/usr/local/lib/python3.10/dist-packages/torch/cuda/__init__.py", line 769, in current_device
#     _lazy_init()
#   File "/usr/local/lib/python3.10/dist-packages/torch/cuda/__init__.py", line 298, in _lazy_init
#     torch._C._cuda_init()
# RuntimeError: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/gradio/routes.py", line 488, in run_predict
#     output = await app.get_blocks().process_api(
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 1431, in process_api
#     result = await self.call_function(
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 1117, in call_function
#     prediction = await utils.async_iteration(iterator)
#   File "/usr/local/lib/python3.10/dist-packages/gradio/utils.py", line 350, in async_iteration
#     return await iterator.__anext__()
#   File "/usr/local/lib/python3.10/dist-packages/gradio/utils.py", line 343, in __anext__
#     return await anyio.to_thread.run_sync(
#   File "/usr/local/lib/python3.10/dist-packages/anyio/to_thread.py", line 33, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(
#   File "/usr/local/lib/python3.10/dist-packages/anyio/_backends/_asyncio.py", line 877, in run_sync_in_worker_thread
#     return await future
#   File "/usr/local/lib/python3.10/dist-packages/anyio/_backends/_asyncio.py", line 807, in run
#     result = context.run(func, *args)
#   File "/usr/local/lib/python3.10/dist-packages/gradio/utils.py", line 326, in run_sync_iterator_async
#     return next(iterator)
#   File "/usr/local/lib/python3.10/dist-packages/gradio/utils.py", line 695, in gen_wrapper
#     yield from f(*args, **kwargs)
#   File "/content/Fooocus/webui.py", line 27, in generate_clicked
#     import ldm_patched.modules.model_management as model_management
#   File "/content/Fooocus/ldm_patched/modules/model_management.py", line 118, in <module>
#     total_vram = get_total_memory(get_torch_device()) / (1024 * 1024)
#   File "/content/Fooocus/ldm_patched/modules/model_management.py", line 87, in get_torch_device
#     return torch.device(torch.cuda.current_device())
#   File "/usr/local/lib/python3.10/dist-packages/torch/cuda/__init__.py", line 769, in current_device
#     _lazy_init()
#   File "/usr/local/lib/python3.10/dist-packages/torch/cuda/__init__.py", line 298, in _lazy_init
#     torch._C._cuda_init()
# RuntimeError: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/gradio/routes.py", line 488, in run_predict
#     output = await app.get_blocks().process_api(
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 1431, in process_api
#     result = await self.call_function(
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 1117, in call_function
#     prediction = await utils.async_iteration(iterator)
#   File "/usr/local/lib/python3.10/dist-packages/gradio/utils.py", line 350, in async_iteration
#     return await iterator.__anext__()
#   File "/usr/local/lib/python3.10/dist-packages/gradio/utils.py", line 343, in __anext__
#     return await anyio.to_thread.run_sync(
#   File "/usr/local/lib/python3.10/dist-packages/anyio/to_thread.py", line 33, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(
#   File "/usr/local/lib/python3.10/dist-packages/anyio/_backends/_asyncio.py", line 877, in run_sync_in_worker_thread
#     return await future
#   File "/usr/local/lib/python3.10/dist-packages/anyio/_backends/_asyncio.py", line 807, in run
#     result = context.run(func, *args)
#   File "/usr/local/lib/python3.10/dist-packages/gradio/utils.py", line 326, in run_sync_iterator_async
#     return next(iterator)
#   File "/usr/local/lib/python3.10/dist-packages/gradio/utils.py", line 695, in gen_wrapper
#     yield from f(*args, **kwargs)
#   File "/content/Fooocus/webui.py", line 27, in generate_clicked
#     import ldm_patched.modules.model_management as model_management
#   File "/content/Fooocus/ldm_patched/modules/model_management.py", line 118, in <module>
#     total_vram = get_total_memory(get_torch_device()) / (1024 * 1024)
#   File "/content/Fooocus/ldm_patched/modules/model_management.py", line 87, in get_torch_device
#     return torch.device(torch.cuda.current_device())
#   File "/usr/local/lib/python3.10/dist-packages/torch/cuda/__init__.py", line 769, in current_device
#     _lazy_init()
#   File "/usr/local/lib/python3.10/dist-packages/torch/cuda/__init__.py", line 298, in _lazy_init
#     torch._C._cuda_init()
# RuntimeError: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx
# Keyboard interruption in main thread... closing server.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 2199, in block_thread
#     time.sleep(0.1)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/Fooocus/entry_with_update.py", line 46, in <module>
#     from launch import *
#   File "/content/Fooocus/launch.py", line 109, in <module>
#     from webui import *
#   File "/content/Fooocus/webui.py", line 616, in <module>
#     shared.gradio_root.launch(
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 2115, in launch
#     self.block_thread()
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 2203, in block_thread
#     self.server.close()
#   File "/usr/local/lib/python3.10/dist-packages/gradio/networking.py", line 49, in close
#     self.thread.join()
#   File "/usr/lib/python3.10/threading.py", line 1096, in join
#     self._wait_for_tstate_lock()
#   File "/usr/lib/python3.10/threading.py", line 1116, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
# KeyboardInterrupt
# Killing tunnel 127.0.0.1:7865 <> https://be6b36259ad818009c.gradio.live
# ^C
